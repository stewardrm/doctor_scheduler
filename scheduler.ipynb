# %% [markdown]
# This program creates a monthly schedule for 5 doctors.  There are two user input sections:
#
#     1.  Requirements.  Doctors are labeled A, B, C, D, E.
#         User inputs are accepted by changing the numbers associated with the following variables:
#         a. (num_days_in_month) number of days in the current month,
#         b. (max_days_in_row) the maximum allowable days in a row a doctor is allowed to be scheduled,
#         c. (days_unavail) days each doctor is not available.  numbers represent calendar dates,
#         d. (doctor_shifts) the minimum and maximum number (inclusive) of shifts each doctor must have.
#         e. (allow_day_night_double) If set to False will not allow a doctor to be scheduled for a day shift immediately
#            followed by a night shift.  Takes values True and False
#         f. (allow_night_day_double) If set to False will not allow a doctor to be scheduled for a night shift immediately
#            followed by a day shift.  Takes values True and False
#           If a schedule cannot be found to satisfy all of these requirements an error message will be given
#           without producing a schedule.
#
#     2.  Request preferences.  The algorithm will attempt to honor requests to the extent possible
#         a.  (req_days_off) The days a doctor requests to have off.
#         b.  (ideal_num_shifts) The ideal number of shifts a doctor has in the month
#         c.  (shift_type_pref) The preferred shift for each doctor
#
#   (prev_month) represents the schedule for the prevous month.  Only the last 6 numbers matter in this data structure.  Its
#   purpose is only to make sure the requirements are satisifed as the month crosses over.
#
#         Except for the two boolean variables, only change numbers

# %%
#Schedule requirements.  Any created schedule must conform to these values
num_days_in_month=31
max_days_in_row=5
days_unavail = {"A": {"Day": [1,2,3], "Night": [1,2,3]}, "B": {"Day": [4,5], "Night": [4]}, "C": {"Day":[7,8,9],"Night":[7,8]}, "D": {"Day":[15],"Night":[15]}, "E": {"Day": [15], "Night": [15]}}
allow_day_night_double=False #True will allow day_night_doubles
allow_night_day_double=False #True will allow night_day_doubles
doctor_shifts = {"A": [16, 20], "B": [16, 20], "C": [16, 20], "D": [16, 20], "E": [16, 20]}
prev_month=None  

#requests/goals  adjust numbers to the right of the "=" sign for ideal_num_shifts and req_days_off.  Interchange "Day" and "Night" for
     #shift_type_pref
ideal_num_shifts = {"A": 16, "B": 16, "C": 20, "D": 19, "E": 18}
req_days_off = {"A": {"Day": [1,2,3], "Night": [1,2,3]}, "B": {"Day": [4,5,6], "Night": [4,5,6]}, "C": {"Day":[7,8,9],"Night":[7,8,9]}, "D": {"Day":[10,11,12],"Night":[10,11,12]}, "E": {"Day": [13,14,15], "Night": [13,14,15]}}
shift_type_pref={"A": "Day", "B": "Day", "C": "Day", "D": "Night", "E": "Night"}


#this is an example schedule for the previous month.  The schedule builder will take into account
#the ending days of this schedule when building the next month to ensure work rules are enforced

# prev_month={'A': {'Day1': [4, 5, 13, 18, 20, 25],
#   'Day2': [8, 9, 14, 15, 19],
#   'Night': [1, 2, 6, 21, 22, 26, 27, 28]},
#  'B': {'Day1': [14, 15, 19, 21, 22, 27, 28, 30],
#   'Day2': [3, 4, 7, 12, 13, 20, 26, 29, 31],
#   'Night': [8, 9]},
#  'C': {'Day1': [6, 17],
#   'Day2': [1, 2, 16, 21, 22, 27, 28],
#   'Night': [3, 7, 10, 11, 12, 13, 18, 23, 24, 29]},
#  'D': {'Day1': [3, 8, 9, 11, 23, 24, 29],
#   'Day2': [10],
#   'Night': [4, 5, 14, 15, 16, 17, 20, 25, 30, 31]},
#  'E': {'Day1': [1, 2, 7, 10, 12, 16, 26, 31],
#   'Day2': [5, 6, 11, 17, 18, 23, 24, 25, 30],
#   'Night': [19]}}

# %%
#run this cell to initialize scheduler

import doctor_scheduler as ds
scheduler_object=ds.DoctorScheduling(num_days_in_month, doctor_shifts, days_unavail, allow_day_night_double, allow_night_day_double, max_days_in_row, req_days_off, ideal_num_shifts, shift_type_pref, prev_month=None)
scheduler_object.assign_shifts()
# Out:
# Scheduler initialized successfully.

# %%
#search for schedules.  Adjust the weights to favor one category over the other.  For example if you really want to give
#people their requested days_off adjust the weight of days_off to say .7 and leave the others at .1.  Experiement for best 
#results.  The number in "mountain_climber" represents how many search iterations will be conduct.  Higher the better, but it
#takes more time to run.

weight={"pattern":.2,"days_off":.2,"num_shifts":.4,"shift_type":2}
#scheduler_object.mountain_climber(100000,weight)
scheduler_object.simulated_annealing(100000,weight)
# Out:
# current loss:  0.5766689075630254
# final loss:  0.5441996609169983

# %%
#run this cell to view some schedule stats and the actual created schedule itself.

scheduler_object.calculate_percentage_days_off(scheduler_object.scheduler)
print("")
scheduler_object.actual_vs_requested_shifts(scheduler_object.scheduler)
print("")
scheduler_object.percentage_of_preferred_shift(scheduler_object.scheduler)
print("")
scheduler_object.is_schedule_legal(scheduler_object.scheduler,True,None)
print("")
scheduler_object.print_horizontal(scheduler_object.scheduler)
# Out:
# A  percent or requested days off actually off: 100.0
# B  percent or requested days off actually off: 100.0
# C  percent or requested days off actually off: 100.0
# D  percent or requested days off actually off: 88.89
# E  percent or requested days off actually off: 100.0
#
# A  req: 16  actual shifts: 17
# B  req: 16  actual shifts: 19
# C  req: 20  actual shifts: 20
# D  req: 19  actual shifts: 19
# E  req: 18  actual shifts: 18
#
# A  percent of preferred shifts to actual shifts:  0.9411764705882353
# B  percent of preferred shifts to actual shifts:  0.8947368421052632
# C  percent of preferred shifts to actual shifts:  0.95
# D  percent of preferred shifts to actual shifts:  0.631578947368421
# E  percent of preferred shifts to actual shifts:  0.8333333333333334
#
# No day to night double shifts scheduled
# No night to day double shifts scheduled
# No one scheduled for more than  5  in a row
# No one scheduled on their unavailable day
# all shift number constraints are complied with
# <style type="text/css">
# #T_f8f58_row0_col0, #T_f8f58_row0_col1, #T_f8f58_row0_col2, #T_f8f58_row0_col8, #T_f8f58_row0_col12, #T_f8f58_row0_col13, #T_f8f58_row0_col15, #T_f8f58_row0_col16, #T_f8f58_row0_col21, #T_f8f58_row0_col22, #T_f8f58_row0_col23, #T_f8f58_row0_col28, #T_f8f58_row0_col29, #T_f8f58_row0_col30, #T_f8f58_row1_col3, #T_f8f58_row1_col4, #T_f8f58_row1_col5, #T_f8f58_row1_col9, #T_f8f58_row1_col10, #T_f8f58_row1_col11, #T_f8f58_row1_col17, #T_f8f58_row1_col18, #T_f8f58_row1_col19, #T_f8f58_row1_col24, #T_f8f58_row1_col25, #T_f8f58_row1_col26, #T_f8f58_row2_col5, #T_f8f58_row2_col6, #T_f8f58_row2_col7, #T_f8f58_row2_col8, #T_f8f58_row2_col11, #T_f8f58_row2_col15, #T_f8f58_row2_col16, #T_f8f58_row2_col20, #T_f8f58_row2_col21, #T_f8f58_row2_col26, #T_f8f58_row2_col27, #T_f8f58_row3_col0, #T_f8f58_row3_col6, #T_f8f58_row3_col9, #T_f8f58_row3_col10, #T_f8f58_row3_col14, #T_f8f58_row3_col17, #T_f8f58_row3_col18, #T_f8f58_row3_col19, #T_f8f58_row3_col22, #T_f8f58_row3_col23, #T_f8f58_row3_col27, #T_f8f58_row3_col28, #T_f8f58_row4_col1, #T_f8f58_row4_col2, #T_f8f58_row4_col3, #T_f8f58_row4_col4, #T_f8f58_row4_col7, #T_f8f58_row4_col12, #T_f8f58_row4_col13, #T_f8f58_row4_col14, #T_f8f58_row4_col20, #T_f8f58_row4_col24, #T_f8f58_row4_col25, #T_f8f58_row4_col29, #T_f8f58_row4_col30 {
#   color: black;
# }
# #T_f8f58_row0_col3, #T_f8f58_row0_col4, #T_f8f58_row0_col9, #T_f8f58_row0_col14, #T_f8f58_row0_col17, #T_f8f58_row0_col25, #T_f8f58_row0_col27, #T_f8f58_row1_col2, #T_f8f58_row1_col6, #T_f8f58_row1_col12, #T_f8f58_row1_col15, #T_f8f58_row1_col20, #T_f8f58_row1_col22, #T_f8f58_row1_col23, #T_f8f58_row1_col29, #T_f8f58_row1_col30, #T_f8f58_row2_col0, #T_f8f58_row2_col1, #T_f8f58_row2_col10, #T_f8f58_row2_col13, #T_f8f58_row2_col18, #T_f8f58_row2_col19, #T_f8f58_row2_col24, #T_f8f58_row2_col28, #T_f8f58_row3_col7, #T_f8f58_row3_col8, #T_f8f58_row3_col11, #T_f8f58_row3_col16, #T_f8f58_row3_col21, #T_f8f58_row4_col5, #T_f8f58_row4_col26 {
#   color: green;
# }
# #T_f8f58_row0_col5, #T_f8f58_row0_col6, #T_f8f58_row0_col7, #T_f8f58_row0_col10, #T_f8f58_row0_col11, #T_f8f58_row0_col18, #T_f8f58_row0_col19, #T_f8f58_row0_col24, #T_f8f58_row0_col26, #T_f8f58_row1_col0, #T_f8f58_row1_col1, #T_f8f58_row1_col13, #T_f8f58_row1_col14, #T_f8f58_row1_col16, #T_f8f58_row1_col21, #T_f8f58_row1_col27, #T_f8f58_row1_col28, #T_f8f58_row2_col2, #T_f8f58_row2_col3, #T_f8f58_row2_col4, #T_f8f58_row2_col9, #T_f8f58_row2_col12, #T_f8f58_row2_col17, #T_f8f58_row2_col22, #T_f8f58_row2_col23, #T_f8f58_row2_col25, #T_f8f58_row2_col29, #T_f8f58_row2_col30, #T_f8f58_row3_col15, #T_f8f58_row3_col20, #T_f8f58_row4_col8 {
#   color: blue;
# }
# #T_f8f58_row0_col20, #T_f8f58_row1_col7, #T_f8f58_row1_col8, #T_f8f58_row2_col14, #T_f8f58_row3_col1, #T_f8f58_row3_col2, #T_f8f58_row3_col3, #T_f8f58_row3_col4, #T_f8f58_row3_col5, #T_f8f58_row3_col12, #T_f8f58_row3_col13, #T_f8f58_row3_col24, #T_f8f58_row3_col25, #T_f8f58_row3_col26, #T_f8f58_row3_col29, #T_f8f58_row3_col30, #T_f8f58_row4_col0, #T_f8f58_row4_col6, #T_f8f58_row4_col9, #T_f8f58_row4_col10, #T_f8f58_row4_col11, #T_f8f58_row4_col15, #T_f8f58_row4_col16, #T_f8f58_row4_col17, #T_f8f58_row4_col18, #T_f8f58_row4_col19, #T_f8f58_row4_col21, #T_f8f58_row4_col22, #T_f8f58_row4_col23, #T_f8f58_row4_col27, #T_f8f58_row4_col28 {
#   color: red;
# }
# </style>
# <table id="T_f8f58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8f58_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_f8f58_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_f8f58_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_f8f58_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_f8f58_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_f8f58_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_f8f58_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_f8f58_level0_col7" class="col_heading level0 col7" >8</th>
#       <th id="T_f8f58_level0_col8" class="col_heading level0 col8" >9</th>
#       <th id="T_f8f58_level0_col9" class="col_heading level0 col9" >10</th>
#       <th id="T_f8f58_level0_col10" class="col_heading level0 col10" >11</th>
#       <th id="T_f8f58_level0_col11" class="col_heading level0 col11" >12</th>
#       <th id="T_f8f58_level0_col12" class="col_heading level0 col12" >13</th>
#       <th id="T_f8f58_level0_col13" class="col_heading level0 col13" >14</th>
#       <th id="T_f8f58_level0_col14" class="col_heading level0 col14" >15</th>
#       <th id="T_f8f58_level0_col15" class="col_heading level0 col15" >16</th>
#       <th id="T_f8f58_level0_col16" class="col_heading level0 col16" >17</th>
#       <th id="T_f8f58_level0_col17" class="col_heading level0 col17" >18</th>
#       <th id="T_f8f58_level0_col18" class="col_heading level0 col18" >19</th>
#       <th id="T_f8f58_level0_col19" class="col_heading level0 col19" >20</th>
#       <th id="T_f8f58_level0_col20" class="col_heading level0 col20" >21</th>
#       <th id="T_f8f58_level0_col21" class="col_heading level0 col21" >22</th>
#       <th id="T_f8f58_level0_col22" class="col_heading level0 col22" >23</th>
#       <th id="T_f8f58_level0_col23" class="col_heading level0 col23" >24</th>
#       <th id="T_f8f58_level0_col24" class="col_heading level0 col24" >25</th>
#       <th id="T_f8f58_level0_col25" class="col_heading level0 col25" >26</th>
#       <th id="T_f8f58_level0_col26" class="col_heading level0 col26" >27</th>
#       <th id="T_f8f58_level0_col27" class="col_heading level0 col27" >28</th>
#       <th id="T_f8f58_level0_col28" class="col_heading level0 col28" >29</th>
#       <th id="T_f8f58_level0_col29" class="col_heading level0 col29" >30</th>
#       <th id="T_f8f58_level0_col30" class="col_heading level0 col30" >31</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8f58_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_f8f58_row0_col0" class="data row0 col0" >·</td>
#       <td id="T_f8f58_row0_col1" class="data row0 col1" >·</td>
#       <td id="T_f8f58_row0_col2" class="data row0 col2" >·</td>
#       <td id="T_f8f58_row0_col3" class="data row0 col3" >D1</td>
#       <td id="T_f8f58_row0_col4" class="data row0 col4" >D1</td>
#       <td id="T_f8f58_row0_col5" class="data row0 col5" >D2</td>
#       <td id="T_f8f58_row0_col6" class="data row0 col6" >D2</td>
#       <td id="T_f8f58_row0_col7" class="data row0 col7" >D2</td>
#       <td id="T_f8f58_row0_col8" class="data row0 col8" >·</td>
#       <td id="T_f8f58_row0_col9" class="data row0 col9" >D1</td>
#       <td id="T_f8f58_row0_col10" class="data row0 col10" >D2</td>
#       <td id="T_f8f58_row0_col11" class="data row0 col11" >D2</td>
#       <td id="T_f8f58_row0_col12" class="data row0 col12" >·</td>
#       <td id="T_f8f58_row0_col13" class="data row0 col13" >·</td>
#       <td id="T_f8f58_row0_col14" class="data row0 col14" >D1</td>
#       <td id="T_f8f58_row0_col15" class="data row0 col15" >·</td>
#       <td id="T_f8f58_row0_col16" class="data row0 col16" >·</td>
#       <td id="T_f8f58_row0_col17" class="data row0 col17" >D1</td>
#       <td id="T_f8f58_row0_col18" class="data row0 col18" >D2</td>
#       <td id="T_f8f58_row0_col19" class="data row0 col19" >D2</td>
#       <td id="T_f8f58_row0_col20" class="data row0 col20" >N</td>
#       <td id="T_f8f58_row0_col21" class="data row0 col21" >·</td>
#       <td id="T_f8f58_row0_col22" class="data row0 col22" >·</td>
#       <td id="T_f8f58_row0_col23" class="data row0 col23" >·</td>
#       <td id="T_f8f58_row0_col24" class="data row0 col24" >D2</td>
#       <td id="T_f8f58_row0_col25" class="data row0 col25" >D1</td>
#       <td id="T_f8f58_row0_col26" class="data row0 col26" >D2</td>
#       <td id="T_f8f58_row0_col27" class="data row0 col27" >D1</td>
#       <td id="T_f8f58_row0_col28" class="data row0 col28" >·</td>
#       <td id="T_f8f58_row0_col29" class="data row0 col29" >·</td>
#       <td id="T_f8f58_row0_col30" class="data row0 col30" >·</td>
#     </tr>
#     <tr>
#       <th id="T_f8f58_level0_row1" class
